# %%
# %pip install -U llama-index-readers-file pymupdf
# %pip install -U llama-index-core
# %pip install -U llama-index-llms-azure-openai
# %pip install -U llama-index-embeddings-azure-openai
# %pip install -U llama-index-vector-stores-chroma
# %pip install -U python-dotenv

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

# Create data directory safely (Windows / Linux / macOS)
DATA_DIR = Path("data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Load Data

# %%
from pathlib import Path

from llama_index.readers.file import PDFReader
from llama_index.readers.file import PyMuPDFReader

# %%
loader = PyMuPDFReader()
# docs0 = loader.load_data(file=Path("./data/llama2.pdf"))
docs0 = loader.load(file_path=Path("./data/GMDSS_System-IOM_Manual.pdf"))

# %% [markdown]
# By default, the PDF reader creates a separate doc for each page. For the sake of this notebook, we stitch docs together into one doc. This will help us better highlight auto-merging capabilities that “stitch” chunks together later on.

# %%
from llama_index.core import Document

doc_text = "\n\n".join([d.get_content() for d in docs0])
docs = [Document(text=doc_text)]

# %% [markdown]
# ### Parse Chunk Hierarchy from Text, Load into Storage
#
# By default, the hierarchy is:
#
# - 1st level: chunk size 2048
# - 2nd level: chunk size 512
# - 3rd level: chunk size 128

# %%
from llama_index.core.node_parser import HierarchicalNodeParser
from llama_index.core.node_parser import SentenceSplitter

# %%
node_parser = HierarchicalNodeParser.from_defaults()

# %%
nodes = node_parser.get_nodes_from_documents(docs)

# %%
len(nodes)
# Out:
# 1219

# %% [markdown]
# Here we import a simple helper function for fetching “leaf” nodes within a node list. These are nodes that don’t have children of their own.

# %%
from llama_index.core.node_parser import get_leaf_nodes, get_root_nodes

# %%
leaf_nodes = get_leaf_nodes(nodes)

# %%
len(leaf_nodes)
# Out:
# 934

# %%
root_nodes = get_root_nodes(nodes)

# %%
from dotenv import load_dotenv
import os

load_dotenv()

AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
OPENAI_API_VERSION = os.getenv("OPENAI_API_VERSION")

AZURE_CHAT_DEPLOYMENT = os.getenv("AZURE_CHAT_DEPLOYMENT")
AZURE_EMBEDDING_DEPLOYMENT = os.getenv("AZURE_EMBEDDING_DEPLOYMENT")

CHROMA_PERSIST_DIR = os.getenv("CHROMA_PERSIST_DIR")
EMBEDDING_DIMENSIONS = int(os.getenv("EMBEDDING_DIMENSIONS"))

# %%
from llama_index.core.storage.docstore import SimpleDocumentStore
from llama_index.core import StorageContext
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding

docstore = SimpleDocumentStore()

# insert nodes into docstore
docstore.add_documents(nodes)

# define storage context (will include vector store by default too)
storage_context = StorageContext.from_defaults(docstore=docstore)

llm = AzureOpenAI(
    model="gpt-4o",  # logical model name
    deployment_name=AZURE_CHAT_DEPLOYMENT,
    api_key=AZURE_OPENAI_API_KEY,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_version=OPENAI_API_VERSION,
    temperature=0.1,
)

embed_model = AzureOpenAIEmbedding(
    model="text-embedding-3-large",
    deployment_name=AZURE_EMBEDDING_DEPLOYMENT,
    api_key=AZURE_OPENAI_API_KEY,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_version=OPENAI_API_VERSION,
    dimensions=EMBEDDING_DIMENSIONS,  # 3072
)

# %%
from llama_index.core import Settings

Settings.embed_model = embed_model   # AzureOpenAIEmbedding
Settings.llm = llm

# %%
from llama_index.core import VectorStoreIndex

base_index = VectorStoreIndex(
    leaf_nodes,
    storage_context=storage_context,
)
# Out:
# 2026-01-15 12:23:01,240 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:05,503 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:08,282 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:09,731 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:11,335 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:12,441 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:13,978 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:15,795 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:17,226 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:18,722 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:20,050 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:21,254 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:22,453 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:24,081 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:25,359 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:27,220 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:30,033 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:31,913 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:33,843 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:35,241 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:36,840 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:39,219 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:40,737 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:43,332 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:47,134 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:49,117 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:50,914 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:52,824 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:55,190 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:23:58,109 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:03,597 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:08,500 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:10,540 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:12,937 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:14,037 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:15,372 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:17,267 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:19,933 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:22,278 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:25,218 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:27,025 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:29,389 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:31,558 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:33,876 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:35,388 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:37,561 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:39,039 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:40,345 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:41,816 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:43,017 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:44,174 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:45,223 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:46,506 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:47,613 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:48,997 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:50,368 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:51,250 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:52,520 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:53,400 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:54,382 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:55,856 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:56,944 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:24:58,066 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:00,047 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:01,566 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:02,996 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:04,550 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:05,859 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:07,263 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:08,376 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:09,444 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:11,016 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:12,652 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:13,870 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:15,470 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:16,423 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:17,978 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:19,415 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:20,883 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:22,642 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:24,491 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:25,920 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:27,478 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:29,037 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:31,180 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:35,666 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:37,330 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:39,289 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:40,334 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:41,627 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:43,973 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:45,739 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:47,765 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:25:50,879 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"

# %% [markdown]
# ### Define Retriever

# %%
from llama_index.core.retrievers import AutoMergingRetriever

# %%
base_retriever = base_index.as_retriever(similarity_top_k=6)
retriever = AutoMergingRetriever(base_retriever, storage_context, verbose=True)

# %%
query_str = (
    "how to Replace the fuse in the Transceiver Unit"
)

nodes = retriever.retrieve(query_str)
base_nodes = base_retriever.retrieve(query_str)
# Out:
# 2026-01-15 12:27:49,951 - INFO - Retrying request to /embeddings in 0.479918 seconds
# 2026-01-15 12:27:53,649 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:27:53,932 - INFO - > Merging 2 nodes into parent node.
# > Parent node id: 23ecde3b-a40b-4ee7-8695-7fd14e12ddc3.
# > Parent node text: a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L...
# > Merging 2 nodes into parent node.
# > Parent node id: 23ecde3b-a40b-4ee7-8695-7fd14e12ddc3.
# > Parent node text: a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L...
# 2026-01-15 12:27:54,552 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"

# %%
len(nodes)
# Out:
# 5

# %%
len(base_nodes)
# Out:
# 6

# %%
for node in nodes:
    print("=" * 80)
    print(node.text[:10000])
    print("Metadata:", node.metadata)
# Out:
# ================================================================================
# a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L/nit
# Replacing the fuse in the Transceiver Unit
# One fuse is installed in the Transceiver Unit. If the fuse is blown, do as follows:
# 1.
# Track down why the fuse was blown and solve the problem.
# 2.
# Take out the old fuse.
# 3.
# Insert the new fuse. The fuse rating is 10 A T.
# Figure 3: Replacing the fuse in the SAILOR 7226 VHF Transceiver Unit
# 98-171832-A
#
# Chapter 3: Service & maintenanc
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 47 of 307
# Metadata: {}
# ================================================================================
# Replacing the fuse in theTransceiver L/nit
#
#
#
# List of alerts
# The table below shows the alerts you may see in the Bridge Alert Management (BAM)
# system.
#
# ID
# Instance Priority Category
# Title
# Description
# 3023
# 1
# C
# B
# PS COMM Lost
# Power supply
# communication lost
# 3023
# 2
#
#
# B
# BATT VOLT Low
# Battery and charger.
# Voltage below limit
# 3023
# 3
#
#
# B
# BATT VOLT High
# Battery and charger.
# Metadata: {}
# ================================================================================
# Replacing the fuse in theTransceiver L/nit
# Warranty and returning units for repair
# Should your Cobham SATCOM product fail, contact your dealer or installer, or the nearest
# Cobham SATCOM partner. You will find the partner details on
# www.cobhamsatcom.com/where-to-buy. You can also access www.cobhamsatcom.com and
# select COBHAM SYNC PARTNER PORTAL, which may help you solve the problem.
# Metadata: {}
# ================================================================================
# Open the transponder by turning the screw ring counter clockwise.
# 2.
# Remove the battery unit (lower half) of the transponder, by disconnecting the
# 3.
# battery plug.
# 4.
# Make sure the o-ring is in place at the upper part of the transponder.
# 5.
# Please make sure that the enclosed silicagel bag is placed inside the Tron SART.
# 6.
# Please also fit the enclosed inti corrosion adhesive tape to the inside of the battery before
# assembly of the unit.
# 7.
# Metadata: {}
# ================================================================================
# 7.
# Connect the new battery unit and attach it to the upper part.
# 8.
# Tighten the screw ring by turning it clockwise.
# 9.
# Test the transponder according to procedure in chapter 5.3.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 108 of 307
# Metadata: {}

# %%
for node in base_nodes:
    print("=" * 80)
    print(node.text[:10000])
    print("Metadata:", node.metadata)
# Out:
# ================================================================================
# a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L/nit
# Replacing the fuse in the Transceiver Unit
# One fuse is installed in the Transceiver Unit. If the fuse is blown, do as follows:
# 1.
# Track down why the fuse was blown and solve the problem.
# 2.
# Take out the old fuse.
# 3.
# Insert the new fuse.
# Metadata: {}
# ================================================================================
# 2.
# Take out the old fuse.
# 3.
# Insert the new fuse. The fuse rating is 10 A T.
# Figure 3: Replacing the fuse in the SAILOR 7226 VHF Transceiver Unit
# 98-171832-A
#
# Chapter 3: Service & maintenanc
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 47 of 307
# Metadata: {}
# ================================================================================
# Replacing the fuse in theTransceiver L/nit
#
#
#
# List of alerts
# The table below shows the alerts you may see in the Bridge Alert Management (BAM)
# system.
#
# ID
# Instance Priority Category
# Title
# Description
# 3023
# 1
# C
# B
# PS COMM Lost
# Power supply
# communication lost
# 3023
# 2
#
#
# B
# BATT VOLT Low
# Battery and charger.
# Voltage below limit
# 3023
# 3
#
#
# B
# BATT VOLT High
# Battery and charger.
# Metadata: {}
# ================================================================================
# Replacing the fuse in theTransceiver L/nit
# Warranty and returning units for repair
# Should your Cobham SATCOM product fail, contact your dealer or installer, or the nearest
# Cobham SATCOM partner. You will find the partner details on
# www.cobhamsatcom.com/where-to-buy. You can also access www.cobhamsatcom.com and
# select COBHAM SYNC PARTNER PORTAL, which may help you solve the problem.
# Metadata: {}
# ================================================================================
# Open the transponder by turning the screw ring counter clockwise.
# 2.
# Remove the battery unit (lower half) of the transponder, by disconnecting the
# 3.
# battery plug.
# 4.
# Make sure the o-ring is in place at the upper part of the transponder.
# 5.
# Please make sure that the enclosed silicagel bag is placed inside the Tron SART.
# 6.
# Please also fit the enclosed inti corrosion adhesive tape to the inside of the battery before
# assembly of the unit.
# 7.
# Metadata: {}
# ================================================================================
# 7.
# Connect the new battery unit and attach it to the upper part.
# 8.
# Tighten the screw ring by turning it clockwise.
# 9.
# Test the transponder according to procedure in chapter 5.3.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 108 of 307
# Metadata: {}

# %% [markdown]
# ### Plug it into Query Engine

# %%
from llama_index.core.query_engine import RetrieverQueryEngine

# %%
query_engine = RetrieverQueryEngine.from_args(retriever)
base_query_engine = RetrieverQueryEngine.from_args(base_retriever)

# %%
response = query_engine.query(query_str)
# Out:
# 2026-01-15 12:28:36,880 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:28:37,158 - INFO - > Merging 2 nodes into parent node.
# > Parent node id: 23ecde3b-a40b-4ee7-8695-7fd14e12ddc3.
# > Parent node text: a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L...
# > Merging 2 nodes into parent node.
# > Parent node id: 23ecde3b-a40b-4ee7-8695-7fd14e12ddc3.
# > Parent node text: a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L...
# 2026-01-15 12:28:41,185 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"

# %%
response = query_engine.query(query_str)
# Out:
# 2026-01-15 12:28:42,401 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:28:42,685 - INFO - > Merging 2 nodes into parent node.
# > Parent node id: 23ecde3b-a40b-4ee7-8695-7fd14e12ddc3.
# > Parent node text: a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L...
# > Merging 2 nodes into parent node.
# > Parent node id: 23ecde3b-a40b-4ee7-8695-7fd14e12ddc3.
# > Parent node text: a CAM.
# DOCUMENT: GMDSS SYSTEM IOM MANUAL
# Page 46 of 307
#
#
# Replacing the fuse in theTransceiver L...
# 2026-01-15 12:28:44,157 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"

# %%
print(str(response))
# Out:
# To replace the fuse in the Transceiver Unit, follow these steps:
#
# 1. Identify and resolve the issue that caused the fuse to blow.
# 2. Remove the old fuse from the unit.
# 3. Insert a new fuse with a rating of 10 A T.

# %%
base_response = base_query_engine.query(query_str)
# Out:
# 2026-01-15 12:28:45,657 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-15 12:28:47,344 - INFO - HTTP Request: POST https://nilup-mgaf895d-eastus.cognitiveservices.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"

# %%
print(str(base_response))
# Out:
# To replace the fuse in the Transceiver Unit, follow these steps:
#
# 1. Identify and resolve the issue that caused the fuse to blow.
# 2. Remove the old fuse from the unit.
# 3. Insert a new fuse with a rating of 10 A T.

# %% [markdown]
# ### Evaluation
